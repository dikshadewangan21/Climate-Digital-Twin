# %% [markdown]
# # ClimateTwin AI — Multi-year Chhattisgarh LSTM training
# This notebook downloads multi-year ERA5-Land data for the 33 district representative points, prepares 7-day sequences and trains the ClimateTwin LSTM.

# %%
# !pip -q install fastapi uvicorn requests pandas numpy scikit-learn joblib torch

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# Upload `ClimateTwin_AI_backend_v2.zip` from your computer.

# %%
import zipfile, os, pathlib
zip_name = next(iter(uploaded))
with zipfile.ZipFile(zip_name) as z: z.extractall('/content')
ROOT='/content/backend'
os.chdir(ROOT)
print(os.getcwd())

# %%
# !python scripts/download_historical.py --years 10

# %%
# !python scripts/prepare_training.py

# %%
# !python scripts/train_lstm.py

# %%
from google.colab import files
# !zip -qr /content/ClimateTwin_AI_trained_artifacts.zip datasets/processed/v2 saved_models_v2
files.download('/content/ClimateTwin_AI_trained_artifacts.zip')
